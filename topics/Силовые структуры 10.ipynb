# %%
import pyLDAvis.gensim
#from pipeline import TopicModeller
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")
from gensim import corpora
#pyLDAvis.enable_notebook()
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel, LdaMulticore
#import tm_functions
import matplotlib.pyplot as plt
# %matplotlib inline

import re
import tm_functions

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/midzay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('russian')
STOPLIST = set(stop_words)
SYMBOLS = " ".join(string.punctuation).split(" ") + ["-", "...", "”", "”","«","»"]

# %%
with open('../../../../nlp/preprocessing/stopwords.txt') as sw:
    text =sw.read().splitlines()
for t in text:
    STOPLIST.add(t)
STOPLIST.add('—')

# %%
PATH ='/home/midzay/Mlerning/DATASET/proj_news_viz/small/lemma/'
file='Sil_struktur.csv.bz2'

# %%
data = pd.read_csv(PATH + file , encoding='utf-8')
data.head()
# Out:
#            1914-lenta/                                             url  \
# 0  1999-10-01 12:00:00      https://lenta.ru/news/1999/10/01/skuratov/
# 1  1999-10-04 12:00:00  https://lenta.ru/news/1999/10/04/bank_skandal/
# 2  1999-10-04 12:00:00      https://lenta.ru/news/1999/10/04/chechnya/
# 3  1999-10-06 12:00:00    https://lenta.ru/news/1999/10/06/samara_vaz/
# 4  1999-10-07 12:00:00      https://lenta.ru/news/1999/10/07/baturina/
#
#    edition  topics                                              title  \
# 0      NaN  Россия  Cледствие по делу Скуратова продлено еще на 4 ...
# 1      NaN  Россия                      Зять Ельцина вызван на допрос
# 2      NaN  Россия                        Чечня полностью изолирована
# 3      NaN  Россия  В Самарской области убит директор автомобильно...
# 4      NaN  Россия  Жена Лужкова решила обжаловать в суде действия...
#
#                                                 text              topic  \
# 0  Генеральная прокуратура продлила еще на 4 меся...  Силовые структуры
# 1  Зять президента Ельцина Леонид Дьяченко вызван...  Силовые структуры
# 2  По заявлению командующего объединенной федерал...  Силовые структуры
# 3  Директор фирмы "Эверест" и его жена погибли в ...  Силовые структуры
# 4  Жена московского мэра Елена Батурина обратилас...  Силовые структуры
#
#                                            text_lema
# 0  генеральный прокуратура продлить 4 месяцасрок ...
# 1  зять ельцин леонид дьяченко вызвать допрос бол...
# 2  заявление командующий объединить федеральный г...
# 3  директор фирма эверест жена погибнуть сильный ...
# 4  жена московский мэр елена батурин обратиться ж...

# %%
def pre_proc(text):
    tokens = [tok for tok in text.split() if tok not in STOPLIST]
    return tokens

# %%
data['new_text']=data.text_lema.apply(pre_proc)

# %%
data.drop(data[data.text=='text'].index,inplace=True)

# %%
data.head()
# Out:
#            1914-lenta/                                             url  \
# 0  1999-10-01 12:00:00      https://lenta.ru/news/1999/10/01/skuratov/
# 1  1999-10-04 12:00:00  https://lenta.ru/news/1999/10/04/bank_skandal/
# 2  1999-10-04 12:00:00      https://lenta.ru/news/1999/10/04/chechnya/
# 3  1999-10-06 12:00:00    https://lenta.ru/news/1999/10/06/samara_vaz/
# 4  1999-10-07 12:00:00      https://lenta.ru/news/1999/10/07/baturina/
#
#    edition  topics                                              title  \
# 0      NaN  Россия  Cледствие по делу Скуратова продлено еще на 4 ...
# 1      NaN  Россия                      Зять Ельцина вызван на допрос
# 2      NaN  Россия                        Чечня полностью изолирована
# 3      NaN  Россия  В Самарской области убит директор автомобильно...
# 4      NaN  Россия  Жена Лужкова решила обжаловать в суде действия...
#
#                                                 text              topic  \
# 0  Генеральная прокуратура продлила еще на 4 меся...  Силовые структуры
# 1  Зять президента Ельцина Леонид Дьяченко вызван...  Силовые структуры
# 2  По заявлению командующего объединенной федерал...  Силовые структуры
# 3  Директор фирмы "Эверест" и его жена погибли в ...  Силовые структуры
# 4  Жена московского мэра Елена Батурина обратилас...  Силовые структуры
#
#                                            text_lema  \
# 0  генеральный прокуратура продлить 4 месяцасрок ...
# 1  зять ельцин леонид дьяченко вызвать допрос бол...
# 2  заявление командующий объединить федеральный г...
# 3  директор фирма эверест жена погибнуть сильный ...
# 4  жена московский мэр елена батурин обратиться ж...
#
#                                             new_text
# 0  [генеральный, прокуратура, продлить, 4, месяца...
# 1  [зять, ельцин, леонид, дьяченко, вызвать, допр...
# 2  [заявление, командующий, объединить, федеральн...
# 3  [директор, фирма, эверест, жена, погибнуть, си...
# 4  [жена, московский, мэр, елена, батурин, обрати...

# %% [markdown]
# ### Модель

# %%
# %%time
dictionary = corpora.Dictionary(data['new_text'].values)
# Out:
# CPU times: user 5.25 s, sys: 23.4 ms, total: 5.28 s
# Wall time: 5.28 s

# %%
# %%time
doc_term_matrix = [dictionary.doc2bow(doc) for doc in data['new_text'].values]
# Out:
# CPU times: user 4.05 s, sys: 84 ms, total: 4.14 s
# Wall time: 4.15 s

# %%
num_topic=10

# %%
# %%time
ldamodel1 = LdaModel(doc_term_matrix, num_topics=num_topic, id2word = dictionary, passes=10, alpha='auto', eta=None, random_state=42)

perplexity = ldamodel1.log_perplexity(doc_term_matrix)
coherence_model_lda = CoherenceModel(model=ldamodel1, texts=data['new_text'].values, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print(f'Perplexity: {perplexity}')
print(f'Coherence Score: {coherence_lda}')
# Out:
# Perplexity: -8.128657857968932
# Coherence Score: 0.5106188549052162
# CPU times: user 20min, sys: 1.18 s, total: 20min 1s
# Wall time: 17min 38s

# %% [markdown]
# ### Топ-топики в текстах

# %%
# %%time
df_topic_sents_keywords = tm_functions.format_topics_sentences(ldamodel=ldamodel1, corpus=doc_term_matrix,
                                                               texts=data['new_text'].values)

df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
# Out:
# CPU times: user 2min 51s, sys: 212 ms, total: 2min 52s
# Wall time: 2min 52s

# %%
df_dominant_topic.head(15)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0             5.0              0.5323
# 1             1             6.0              0.5763
# 2             2             4.0              0.6816
# 3             3             2.0              0.5578
# 4             4             6.0              0.6875
# 5             5             2.0              0.5120
# 6             6             7.0              0.6859
# 7             7             1.0              0.4483
# 8             8             7.0              0.3206
# 9             9             3.0              0.4063
# 10           10             3.0              0.4110
# 11           11             1.0              0.3866
# 12           12             5.0              0.7696
# 13           13             5.0              0.4272
# 14           14             1.0              0.6076
#
#                                              Keywords  \
# 0                          следствие, решение, москва
# 1                                             миллион
# 2     боевик, район, дагестан, республика, чечня, мвд
# 3                           убийство, дом, автомобиль
# 4                                  миллион, уголовный
# 5                                 мужчина, автомобиль
# 6                  управление, мвд, начальник, россия
# 7                       миллион, сотрудник, уголовный
# 8   следственный, управление, начальник, россия, у...
# 9                                  россия, российский
# 10                               россия, военный, фсб
# 11                   сотрудник, уголовный, преступный
# 12      адвокат, следствие, признать, решение, москва
# 13                                 следствие, решение
# 14  задержать, тысяча, мвд, сотрудник, россия, пре...
#
#                                                  Text
# 0   [генеральный, прокуратура, продлить, 4, месяца...
# 1   [зять, ельцин, леонид, дьяченко, вызвать, допр...
# 2   [заявление, командующий, объединить, федеральн...
# 3   [директор, фирма, эверест, жена, погибнуть, си...
# 4   [жена, московский, мэр, елена, батурин, обрати...
# 5   [159, тысяча, рубль, дневный, выручка, похитит...
# 6   [конец, этап, операция, контроль, приезжий, пр...
# 7   [сотрудник, управление, борьба, экономический,...
# 8   [шесть, привлечь, уголовный, ответственность, ...
# 9   [уголовно-исполнительный, система, начинаться,...
# 10  [московский, городской, приступить, слушание, ...
# 11  [агентство, военный, новость, 15.10.99, старши...
# 12  [московский, городской, отклонить, протест, гл...
# 13  [юрий, скуратов, намеренный, предпринимать, ка...
# 14  [сотрудник, главный, управление, борьба, эконо...

# %% [markdown]
# ### Статистика по топикам

# %%
# %%time
top_indices = df_topic_sents_keywords.groupby('Dominant_Topic')['Perc_Contribution'].nlargest(1).reset_index()['level_1']
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
condition = df_topic_sents_keywords.index.isin(top_indices)
topic_num_keywords = df_topic_sents_keywords[condition][['Dominant_Topic', 'Topic_Keywords']].reset_index(drop=True)

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
# CPU times: user 31.6 ms, sys: 3.99 ms, total: 35.6 ms
# Wall time: 34.8 ms

# %% [markdown]
# ### График по времени

# %%
# %%time
data['date'] = data['url'].apply(lambda x: pd.to_datetime('-'.join(x.split('/')[4:7])))
data['year_month'] = data['date'].values.astype('datetime64[M]')

data['topics'] = [ldamodel1.get_document_topics(i) for i in doc_term_matrix]
data['topics_dict'] = data['topics'].apply(lambda x: {i[0]: i[1] for i in x})

for i in range(ldamodel1.num_topics):
    data['topic_' + str(i)] = data['topics_dict'].apply(lambda x: x[i] if i in x.keys() else 0)
    
data = data.sort_values('year_month')

data.loc[data['year_month'] == '1914-09-01 00:00:00', 'year_month'] = pd.Timestamp(year=2014, month=9, day=1, hour=0)

data.to_csv('/home/midzay/Mlerning/DATASET/proj_news_viz/small/update/Sil_struktur_update.csv.bz2',compression='bz2', index=False)
# Out:
# CPU times: user 1min 43s, sys: 136 ms, total: 1min 43s
# Wall time: 1min 43s

# %%
topic_cols = [col for col in data.columns if 'topic_' in col]
a = data.groupby(['year_month'])[topic_cols].mean()#.plot(stacked=True, figsize=(12, 8))

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.stackplot(a.index, a.T.values, labels=list(a.columns))
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))
plt.show()

# %% [markdown]
# ### Слова в топиках

# %%
ldamodel1.print_topics()
# Out:
# [(0,
#   '0.017*"рубль" + 0.016*"колония" + 0.013*"статья" + 0.013*"свобода" + 0.012*"приговорить" + 0.012*"лишение" + 0.011*"область" + 0.010*"следствие" + 0.010*"тысяча" + 0.010*"рф"'),
#  (1,
#   '0.021*"задержать" + 0.014*"рубль" + 0.012*"миллион" + 0.011*"тысяча" + 0.011*"мвд" + 0.010*"сотрудник" + 0.008*"деньга" + 0.008*"уголовный" + 0.008*"россия" + 0.008*"преступный"'),
#  (2,
#   '0.015*"мужчина" + 0.011*"задержать" + 0.009*"убийство" + 0.008*"подозревать" + 0.008*"дом" + 0.007*"женщина" + 0.007*"уголовный" + 0.007*"место" + 0.007*"автомобиль" + 0.007*"сотрудник"'),
#  (3,
#   '0.026*"россия" + 0.015*"2015" + 0.013*"российский" + 0.009*"военный" + 0.009*"2016" + 0.008*"украина" + 0.007*"фсб" + 0.006*"ведомство" + 0.006*"гражданин" + 0.005*"государство"'),
#  (4,
#   '0.020*"боевик" + 0.013*"район" + 0.011*"дагестан" + 0.011*"республика" + 0.011*"сотрудник" + 0.010*"чечня" + 0.009*"орган" + 0.009*"правоохранительный" + 0.008*"мвд" + 0.008*"спецоперация"'),
#  (5,
#   '0.017*"адвокат" + 0.013*"обвинять" + 0.010*"следствие" + 0.010*"признать" + 0.010*"убийство" + 0.009*"решение" + 0.009*"обвинение" + 0.008*"приговор" + 0.008*"судья" + 0.007*"москва"'),
#  (6,
#   '0.016*"рубль" + 0.014*"миллион" + 0.012*"бывший" + 0.010*"следствие" + 0.008*"уголовный" + 0.008*"хищение" + 0.007*"арест" + 0.007*"мошенничество" + 0.007*"средство" + 0.007*"миллиард"'),
#  (7,
#   '0.017*"следственный" + 0.016*"управление" + 0.014*"мвд" + 0.013*"сотрудник" + 0.011*"комитет" + 0.010*"проверка" + 0.009*"начальник" + 0.009*"россия" + 0.009*"уголовный" + 0.008*"орган"'),
#  (8,
#   '0.021*"убийство" + 0.009*"следствие" + 0.008*"версия" + 0.007*"издание" + 0.007*"газета" + 0.007*"брат" + 0.006*"писать" + 0.005*"следователь" + 0.005*"бывший" + 0.005*"захарченко"'),
#  (9,
#   '0.010*"взрыв" + 0.010*"теракт" + 0.008*"устройство" + 0.008*"погибнуть" + 0.008*"статья" + 0.008*"2014" + 0.007*"произойти" + 0.007*"взрывной" + 0.006*"россия" + 0.006*"уголовный"')]

# %% [markdown]
# ### Топ слова.

# %%
word_counts = {}
for s in tqdm_notebook(doc_term_matrix):
    for w in s:
        if w[0] not in word_counts:
            word_counts[w[0]] = w[1]
        else:
            word_counts[w[0]] += w[1]
# Out:
# HBox(children=(IntProgress(value=0, max=31361), HTML(value='')))

# %%
sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

# %%
for w in sorted_word_counts[:50]:
    print(f'{dictionary[w[0]]} - {w[1]} times.')
# Out:
# задержать - 21905 times.
# уголовный - 20054 times.
# россия - 19397 times.
# сотрудник - 19318 times.
# следствие - 19053 times.
# убийство - 17133 times.
# москва - 16817 times.
# рф - 16676 times.
# рубль - 15361 times.
# мвд - 14635 times.
# орган - 12756 times.
# статья - 12686 times.
# данные - 12632 times.
# управление - 12570 times.
# новость - 12046 times.
# следственный - 11888 times.
# бывший - 11820 times.
# преступление - 11699 times.
# миллион - 11622 times.
# возбудить - 10927 times.
# подозревать - 10160 times.
# правоохранительный - 10133 times.
# район - 9550 times.
# прокуратура - 9461 times.
# область - 9338 times.
# интерфакс - 9289 times.
# боевик - 9260 times.
# адвокат - 8993 times.
# обвинение - 8913 times.
# обвинять - 8824 times.
# источник - 8475 times.
# информация - 8315 times.
# дом - 8226 times.
# тысяча - 8214 times.
# агентство - 7967 times.
# ход - 7934 times.
# версия - 7802 times.
# часть - 7691 times.
# комитет - 7614 times.
# московский - 7590 times.
# ук - 7541 times.
# фсб - 7425 times.
# следователь - 7372 times.
# место - 7207 times.
# начальник - 6907 times.
# глава - 6903 times.
# александр - 6887 times.
# обнаружить - 6742 times.
# незаконный - 6684 times.
# признать - 6564 times.
